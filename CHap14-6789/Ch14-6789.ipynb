# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('lena.png', 0)
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])

plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])

plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])

plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])


plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('lena.png',0)
edges = cv2.Canny(img,100,200)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
from csv import field_size_limit
import numpy as np
import cv2
im = cv2.imread('ankh.jpg')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,240,255,0)

plt.figure(figsize=(24, 8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'), plt.xticks([]), plt.yticks([])

plt.subplot(1,3,2),plt.imshow(imgray,cmap = 'gray')
plt.title('imgray'), plt.xticks([]), plt.yticks([])

plt.subplot(1,3,3),plt.imshow(thresh,cmap = 'gray')
plt.title('threshold'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
from csv import field_size_limit
import numpy as np
import cv2
im = cv2.imread('ankh.jpg')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,240,255,0)
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()
img0 = cv2.drawContours(img0, contours, 2, (255,0,0), 2)
img1 = cv2.drawContours(img1, contours, 3, (255,0,0), 3)

plt.figure(figsize=(24, 8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'), plt.xticks([]), plt.yticks([])

plt.subplot(1,3,2),plt.imshow(img0,cmap = 'gray')
plt.title('imgray'), plt.xticks([]), plt.yticks([])

plt.subplot(1,3,3),plt.imshow(img1,cmap = 'gray')
plt.title('threshold'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
print(contours)
# Out:
# (array([[[  0,   0]],
#
#        [[  0, 499]],
#
#        [[769, 499]],
#
#        [[769,   0]]], dtype=int32), array([[[339, 456]],
#
#        [[340, 455]],
#
#        [[341, 456]],
#
#        [[341, 457]],
#
#        [[340, 458]],
#
#        [[339, 457]]], dtype=int32), array([[[427, 424]],
#
#        [[428, 423]],
#
#        [[429, 424]],
#
#        [[429, 425]],
#
#        [[428, 426]],
#
#        [[427, 425]]], dtype=int32), array([[[427, 420]],
#
#        [[428, 419]],
#
#        [[429, 420]],
#
#        [[429, 421]],
#
#        [[428, 422]],
#
#        [[427, 421]]], dtype=int32), array([[[426, 415]],
#
#        [[427, 414]],
#
#        [[428, 415]],
#
#        [[427, 416]]], dtype=int32), array([[[421, 368]],
#
#        [[422, 367]],
#
#        [[423, 368]],
#
#        [[422, 369]]], dtype=int32), array([[[510, 244]],
#
#        [[511, 243]],
#
#        [[512, 244]],
#
#        [[511, 245]]], dtype=int32), array([[[495, 244]],
#
#        [[496, 243]],
#
#        [[497, 244]],
#
#        [[496, 245]]], dtype=int32), array([[[358, 233]],
#
#        [[359, 232]],
#
#        [[360, 233]],
#
#        [[359, 234]]], dtype=int32), array([[[415, 193]],
#
#        [[416, 192]],
#
#        [[417, 193]],
#
#        [[416, 194]]], dtype=int32), array([[[375,  41]],
#
#        [[376,  40]],
#
#        [[393,  40]],
#
#        ...,
#
#        [[366,  42]],
#
#        [[369,  42]],
#
#        [[370,  41]]], dtype=int32), array([[[407, 459]],
#
#        [[410, 459]]], dtype=int32), array([[[402, 459]],
#
#        [[404, 459]]], dtype=int32), array([[[399, 459]]], dtype=int32), array([[[424, 457]],
#
#        [[423, 458]],
#
#        [[415, 458]],
#
#        [[415, 459]],
#
#        [[416, 459]],
#
#        [[417, 458]],
#
#        [[426, 458]],
#
#        [[426, 457]]], dtype=int32), array([[[401, 433]]], dtype=int32), array([[[347, 428]],
#
#        [[347, 429]]], dtype=int32), array([[[347, 423]]], dtype=int32), array([[[419, 381]]], dtype=int32), array([[[418, 376]],
#
#        [[418, 377]]], dtype=int32), array([[[417, 368]],
#
#        [[417, 372]]], dtype=int32), array([[[416, 362]],
#
#        [[416, 365]]], dtype=int32), array([[[415, 354]],
#
#        [[415, 359]]], dtype=int32), array([[[414, 351]]], dtype=int32), array([[[414, 349]]], dtype=int32), array([[[413, 344]]], dtype=int32), array([[[411, 328]],
#
#        [[411, 329]]], dtype=int32), array([[[407, 326]]], dtype=int32), array([[[406, 318]],
#
#        [[406, 320]]], dtype=int32), array([[[409, 315]],
#
#        [[409, 319]],
#
#        [[410, 320]],
#
#        [[410, 323]],
#
#        [[410, 320]],
#
#        [[409, 319]]], dtype=int32), array([[[402, 312]]], dtype=int32), array([[[405, 311]]], dtype=int32), array([[[408, 308]],
#
#        [[408, 311]]], dtype=int32), array([[[404, 305]]], dtype=int32), array([[[404, 303]]], dtype=int32), array([[[400, 303]],
#
#        [[401, 304]],
#
#        [[401, 309]],
#
#        [[401, 304]]], dtype=int32), array([[[407, 300]],
#
#        [[407, 305]]], dtype=int32), array([[[399, 296]],
#
#        [[399, 297]],
#
#        [[400, 298]],
#
#        [[400, 299]],
#
#        [[400, 298]],
#
#        [[399, 297]]], dtype=int32), array([[[399, 292]],
#
#        [[399, 293]]], dtype=int32), array([[[398, 286]]], dtype=int32), array([[[401, 283]],
#
#        [[401, 284]]], dtype=int32), array([[[398, 283]],
#
#        [[398, 284]]], dtype=int32), array([[[400, 275]],
#
#        [[400, 279]]], dtype=int32), array([[[396, 271]]], dtype=int32), array([[[399, 268]],
#
#        [[399, 271]]], dtype=int32), array([[[391, 262]],
#
#        [[392, 263]]], dtype=int32), array([[[398, 260]],
#
#        [[398, 262]]], dtype=int32), array([[[397, 255]]], dtype=int32), array([[[394, 255]]], dtype=int32), array([[[401, 254]],
#
#        [[401, 262]],
#
#        [[402, 263]],
#
#        [[402, 269]],
#
#        [[403, 270]],
#
#        [[403, 277]],
#
#        [[404, 278]],
#
#        [[404, 285]],
#
#        [[405, 286]],
#
#        [[405, 292]],
#
#        [[406, 293]],
#
#        [[406, 297]],
#
#        [[406, 292]],
#
#        [[405, 291]],
#
#        [[405, 286]],
#
#        [[404, 285]],
#
#        [[404, 277]],
#
#        [[403, 276]],
#
#        [[403, 270]],
#
#        [[402, 269]],
#
#        [[402, 262]],
#
#        [[401, 261]]], dtype=int32), array([[[389, 254]],
#
#        [[389, 255]],
#
#        [[390, 256]],
#
#        [[390, 258]],
#
#        [[390, 256]],
#
#        [[389, 255]]], dtype=int32), array([[[388, 252]]], dtype=int32), array([[[396, 250]]], dtype=int32), array([[[400, 249]],
#
#        [[400, 251]]], dtype=int32), array([[[379, 249]]], dtype=int32), array([[[400, 247]]], dtype=int32), array([[[386, 244]]], dtype=int32), array([[[385, 241]],
#
#        [[385, 242]]], dtype=int32), array([[[366, 239]],
#
#        [[366, 251]],
#
#        [[365, 252]],
#
#        [[365, 263]],
#
#        [[364, 264]],
#
#        [[364, 278]],
#
#        [[363, 279]],
#
#        [[363, 287]],
#
#        [[362, 288]],
#
#        [[362, 293]],
#
#        [[361, 294]],
#
#        [[361, 301]],
#
#        [[360, 302]],
#
#        [[360, 310]],
#
#        [[359, 311]],
#
#        [[359, 322]],
#
#        [[358, 323]],
#
#        [[358, 329]],
#
#        [[357, 330]],
#
#        [[357, 340]],
#
#        [[356, 341]],
#
#        [[356, 349]],
#
#        [[355, 350]],
#
#        [[355, 358]],
#
#        [[354, 359]],
#
#        [[354, 366]],
#
#        [[353, 367]],
#
#        [[353, 373]],
#
#        [[352, 374]],
#
#        [[353, 375]],
#
#        [[352, 376]],
#
#        [[353, 377]],
#
#        [[352, 378]],
#
#        [[352, 380]],
#
#        [[351, 381]],
#
#        [[351, 391]],
#
#        [[350, 392]],
#
#        [[350, 399]],
#
#        [[349, 400]],
#
#        [[349, 407]],
#
#        [[348, 408]],
#
#        [[348, 410]],
#
#        [[349, 411]],
#
#        [[348, 412]],
#
#        [[348, 421]],
#
#        [[348, 418]],
#
#        [[349, 417]],
#
#        [[349, 411]],
#
#        [[350, 410]],
#
#        [[350, 404]],
#
#        [[351, 403]],
#
#        [[351, 401]],
#
#        [[352, 400]],
#
#        [[352, 393]],
#
#        [[353, 392]],
#
#        [[353, 387]],
#
#        [[354, 386]],
#
#        [[354, 380]],
#
#        [[355, 379]],
#
#        [[355, 366]],
#
#        [[356, 365]],
#
#        [[356, 355]],
#
#        [[357, 354]],
#
#        [[357, 344]],
#
#        [[358, 343]],
#
#        [[358, 337]],
#
#        [[359, 336]],
#
#        [[359, 329]],
#
#        [[360, 328]],
#
#        [[360, 327]],
#
#        [[359, 326]],
#
#        [[360, 325]],
#
#        [[360, 320]],
#
#        [[361, 319]],
#
#        [[361, 313]],
#
#        [[362, 312]],
#
#        [[362, 306]],
#
#        [[363, 305]],
#
#        [[363, 296]],
#
#        [[364, 295]],
#
#        [[364, 286]],
#
#        [[365, 285]],
#
#        [[365, 273]],
#
#        [[366, 272]],
#
#        [[366, 270]],
#
#        [[365, 269]],
#
#        [[365, 264]],
#
#        [[366, 263]],
#
#        [[366, 240]],
#
#        [[367, 239]]], dtype=int32), array([[[367, 234]],
#
#        [[367, 235]]], dtype=int32), array([[[261, 234]],
#
#        [[259, 236]],
#
#        [[260, 236]],
#
#        [[261, 235]],
#
#        [[262, 235]],
#
#        [[263, 234]],
#
#        [[264, 234]]], dtype=int32), array([[[258, 234]]], dtype=int32), array([[[394, 229]],
#
#        [[394, 231]],
#
#        [[393, 232]],
#
#        [[394, 233]],
#
#        [[394, 234]],
#
#        [[394, 233]],
#
#        [[393, 232]],
#
#        [[394, 231]]], dtype=int32), array([[[367, 228]]], dtype=int32), array([[[267, 227]]], dtype=int32), array([[[500, 226]]], dtype=int32), array([[[502, 224]]], dtype=int32), array([[[285, 224]]], dtype=int32), array([[[384, 222]]], dtype=int32), array([[[465, 220]]], dtype=int32), array([[[448, 218]]], dtype=int32), array([[[466, 217]]], dtype=int32), array([[[387, 217]]], dtype=int32), array([[[466, 213]],
#
#        [[466, 215]]], dtype=int32), array([[[288, 211]]], dtype=int32), array([[[258, 210]],
#
#        [[258, 212]],
#
#        [[259, 213]],
#
#        [[259, 214]],
#
#        [[258, 215]],
#
#        [[259, 216]],
#
#        [[259, 218]],
#
#        [[258, 219]],
#
#        [[258, 222]],
#
#        [[259, 223]],
#
#        [[258, 224]],
#
#        [[258, 225]],
#
#        [[259, 226]],
#
#        [[259, 229]],
#
#        [[258, 230]],
#
#        [[258, 231]],
#
#        [[258, 230]],
#
#        [[259, 229]],
#
#        [[260, 230]],
#
#        [[260, 232]],
#
#        [[260, 229]],
#
#        [[259, 228]],
#
#        [[259, 225]],
#
#        [[260, 224]],
#
#        [[261, 225]],
#
#        [[261, 227]],
#
#        [[261, 222]],
#
#        [[261, 223]],
#
#        [[260, 224]],
#
#        [[259, 223]],
#
#        [[259, 216]],
#
#        [[258, 215]],
#
#        [[259, 214]],
#
#        [[259, 211]]], dtype=int32), array([[[455, 209]]], dtype=int32), array([[[379, 207]]], dtype=int32), array([[[392, 206]]], dtype=int32), array([[[381, 205]]], dtype=int32), array([[[482, 204]]], dtype=int32), array([[[386, 199]]], dtype=int32), array([[[277, 196]]], dtype=int32), array([[[502, 190]]], dtype=int32), array([[[370, 189]]], dtype=int32), array([[[346, 183]]], dtype=int32), array([[[400, 181]],
#
#        [[399, 182]]], dtype=int32), array([[[336, 172]],
#
#        [[339, 175]],
#
#        [[339, 176]],
#
#        [[344, 181]],
#
#        [[340, 177]],
#
#        [[340, 176]]], dtype=int32), array([[[335, 170]]], dtype=int32), array([[[325, 155]]], dtype=int32), array([[[323, 149]],
#
#        [[323, 150]],
#
#        [[324, 151]],
#
#        [[323, 152]],
#
#        [[324, 151]],
#
#        [[324, 150]]], dtype=int32), array([[[322, 146]],
#
#        [[322, 147]],
#
#        [[321, 148]],
#
#        [[322, 147]]], dtype=int32), array([[[319, 141]],
#
#        [[319, 144]],
#
#        [[320, 145]],
#
#        [[320, 146]],
#
#        [[320, 145]],
#
#        [[321, 144]],
#
#        [[320, 145]],
#
#        [[319, 144]]], dtype=int32), array([[[316, 134]],
#
#        [[316, 135]],
#
#        [[317, 136]],
#
#        [[317, 139]],
#
#        [[318, 139]],
#
#        [[318, 138]],
#
#        [[317, 137]],
#
#        [[317, 135]]], dtype=int32), array([[[427, 120]]], dtype=int32), array([[[312, 113]],
#
#        [[312, 114]],
#
#        [[313, 115]],
#
#        [[313, 118]],
#
#        [[313, 113]]], dtype=int32), array([[[433, 112]],
#
#        [[433, 113]]], dtype=int32), array([[[313, 111]]], dtype=int32), array([[[433, 110]]], dtype=int32), array([[[425,  92]],
#
#        [[425,  93]],
#
#        [[426,  94]],
#
#        [[426,  95]],
#
#        [[426,  93]]], dtype=int32), array([[[424,  89]],
#
#        [[424,  90]]], dtype=int32), array([[[422,  84]]], dtype=int32), array([[[425,  77]]], dtype=int32), array([[[410,  70]]], dtype=int32), array([[[407,  68]],
#
#        [[408,  69]]], dtype=int32), array([[[373,  68]],
#
#        [[372,  69]],
#
#        [[369,  69]],
#
#        [[368,  70]],
#
#        [[365,  70]],
#
#        [[364,  71]],
#
#        [[362,  71]],
#
#        [[361,  72]],
#
#        [[360,  72]],
#
#        [[359,  73]],
#
#        [[358,  73]],
#
#        [[356,  75]],
#
#        [[354,  75]],
#
#        [[352,  77]],
#
#        [[351,  77]],
#
#        [[351,  78]],
#
#        [[345,  84]],
#
#        [[345,  85]],
#
#        [[343,  87]],
#
#        [[343,  88]],
#
#        [[341,  90]],
#
#        [[341,  92]],
#
#        [[340,  93]],
#
#        [[340,  94]],
#
#        [[339,  95]],
#
#        [[339,  98]],
#
#        [[338,  99]],
#
#        [[338, 107]],
#
#        [[337, 108]],
#
#        [[337, 112]],
#
#        [[338, 113]],
#
#        [[338, 118]],
#
#        [[339, 119]],
#
#        [[339, 124]],
#
#        [[340, 125]],
#
#        [[340, 126]],
#
#        [[341, 127]],
#
#        [[341, 130]],
#
#        [[342, 131]],
#
#        [[342, 133]],
#
#        [[343, 134]],
#
#        [[343, 136]],
#
#        [[344, 137]],
#
#        [[344, 138]],
#
#        [[345, 139]],
#
#        [[345, 140]],
#
#        [[346, 141]],
#
#        [[346, 143]],
#
#        [[347, 144]],
#
#        [[347, 145]],
#
#        [[349, 147]],
#
#        [[349, 149]],
#
#        [[350, 150]],
#
#        [[350, 151]],
#
#        [[352, 153]],
#
#        [[352, 154]],
#
#        [[353, 155]],
#
#        [[353, 156]],
#
#        [[355, 158]],
#
#        [[355, 159]],
#
#        [[358, 162]],
#
#        [[358, 163]],
#
#        [[360, 165]],
#
#        [[360, 166]],
#
#        [[363, 169]],
#
#        [[363, 170]],
#
#        [[380, 187]],
#
#        [[381, 187]],
#
#        [[382, 186]],
#
#        [[383, 186]],
#
#        [[385, 184]],
#
#        [[386, 184]],
#
#        [[394, 176]],
#
#        [[394, 175]],
#
#        [[397, 172]],
#
#        [[397, 171]],
#
#        [[399, 169]],
#
#        [[399, 168]],
#
#        [[402, 165]],
#
#        [[402, 164]],
#
#        [[403, 163]],
#
#        [[403, 162]],
#
#        [[406, 159]],
#
#        [[406, 157]],
#
#        [[409, 154]],
#
#        [[409, 153]],
#
#        [[410, 152]],
#
#        [[410, 151]],
#
#        [[412, 149]],
#
#        [[412, 148]],
#
#        [[413, 147]],
#
#        [[413, 146]],
#
#        [[415, 144]],
#
#        [[415, 142]],
#
#        [[416, 141]],
#
#        [[416, 140]],
#
#        [[418, 138]],
#
#        [[418, 136]],
#
#        [[419, 135]],
#
#        [[419, 133]],
#
#        [[420, 132]],
#
#        [[420, 130]],
#
#        [[421, 129]],
#
#        [[421, 128]],
#
#        [[422, 127]],
#
#        [[422, 125]],
#
#        [[423, 124]],
#
#        [[423, 122]],
#
#        [[424, 121]],
#
#        [[424, 118]],
#
#        [[427, 115]],
#
#        [[427, 111]],
#
#        [[428, 110]],
#
#        [[428, 109]],
#
#        [[427, 108]],
#
#        [[428, 107]],
#
#        [[428, 106]],
#
#        [[427, 105]],
#
#        [[428, 104]],
#
#        [[427, 103]],
#
#        [[427,  99]],
#
#        [[426,  98]],
#
#        [[427,  97]],
#
#        [[426,  97]],
#
#        [[425,  98]],
#
#        [[424,  97]],
#
#        [[424,  95]],
#
#        [[423,  94]],
#
#        [[423,  92]],
#
#        [[421,  90]],
#
#        [[421,  88]],
#
#        [[420,  87]],
#
#        [[420,  86]],
#
#        [[417,  83]],
#
#        [[417,  82]],
#
#        [[416,  82]],
#
#        [[415,  81]],
#
#        [[415,  80]],
#
#        [[413,  78]],
#
#        [[412,  78]],
#
#        [[409,  75]],
#
#        [[408,  75]],
#
#        [[407,  74]],
#
#        [[406,  74]],
#
#        [[404,  72]],
#
#        [[402,  72]],
#
#        [[401,  71]],
#
#        [[400,  71]],
#
#        [[399,  70]],
#
#        [[397,  70]],
#
#        [[396,  69]],
#
#        [[393,  69]],
#
#        [[392,  68]],
#
#        [[375,  68]],
#
#        [[374,  69]]], dtype=int32), array([[[399, 164]],
#
#        [[400, 163]],
#
#        [[401, 164]],
#
#        [[400, 165]]], dtype=int32), array([[[427, 108]],
#
#        [[428, 109]],
#
#        [[428, 110]],
#
#        [[427, 111]],
#
#        [[426, 111]],
#
#        [[425, 110]]], dtype=int32), array([[[423, 108]],
#
#        [[424, 107]],
#
#        [[425, 108]],
#
#        [[424, 109]]], dtype=int32))

# %%
from csv import field_size_limit
import numpy as np
import cv2
im = cv2.imread('rectangle.png')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
ret,thresh = cv2.threshold(imgray,127,255,0)
contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()
img0 = cv2.drawContours(img0, contours, -1, (255,0,0), 2)
img1 = cv2.drawContours(img1, contours, 3, (255,0,0), 3)

plt.figure(figsize=(24, 8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'), plt.xticks([]), plt.yticks([])

plt.subplot(1,3,2),plt.imshow(img0,cmap = 'gray')
plt.title('imgray'), plt.xticks([]), plt.yticks([])

plt.subplot(1,3,3),plt.imshow(img1,cmap = 'gray')
plt.title('threshold'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# Out:
# {'m00': 0.0, 'm10': 0.0, 'm01': 0.0, 'm20': 0.0, 'm11': 0.0, 'm02': 0.0, 'm30': 0.0, 'm21': 0.0, 'm12': 0.0, 'm03': 0.0, 'mu20': 0.0, 'mu11': 0.0, 'mu02': 0.0, 'mu30': 0.0, 'mu21': 0.0, 'mu12': 0.0, 'mu03': 0.0, 'nu20': 0.0, 'nu11': 0.0, 'nu02': 0.0, 'nu30': 0.0, 'nu21': 0.0, 'nu12': 0.0, 'nu03': 0.0}

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img0 = im.copy()
img1 = im.copy()

img0 = cv2.drawContours(img0, contours, 2, (255,0,0), 3)
img1 = cv2.drawContours(img1, contours, 3, (255,0,0), 3)

cnt = contours[2]
M = cv2.moments(cnt)

print(M)
# Out:
# {'m00': 65370.5, 'm10': 13103608.666666666, 'm01': 13151215.5, 'm20': 3197256720.25, 'm11': 2636022409.7916665, 'm02': 2868596609.75, 'm30': 869656461189.3, 'm21': 643374720610.4667, 'm12': 574933200511.9333, 'm03': 666738720395.65, 'mu20': 570619933.1802707, 'mu11': -157233.97732686996, 'mu02': 222839439.04700327, 'mu30': -1281563.3732910156, 'mu21': 214710027.48236084, 'mu12': -17759949.608444214, 'mu03': -26122568.747680664, 'nu20': 0.13353137622695896, 'nu11': -3.6794489924456324e-05, 'nu02': 0.052146893656077956, 'nu30': -1.172966395113851e-06, 'nu21': 0.00019651595245270126, 'nu12': -1.6255008924080726e-05, 'nu03': -2.3908997349382615e-05}

# %%
cx = int(M['m10']/M['m00'])
cy = int(M['m01']/M['m00'])
img0 = cv2.rectangle(img0, (cx-2,cy-2),(cx+2,cy+2),(0,0,255),2)

im = cv2.imread('rectangle.png')
imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
thresh = cv2.adaptiveThreshold(imgray,255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)

epsilon = 0.1*cv2.arcLength(cnt,True)
approx = cv2.approxPolyDP(cnt,epsilon,True)
 
plt.figure(figsize=(24,8))
plt.subplot(1,3,1),plt.imshow(im)
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,2),plt.imshow(img0,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(1,3,3),plt.imshow(img1,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.show()
